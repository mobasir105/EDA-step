# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("product_data.csv")

# %%
df.sample(5)
# Out:
#     ProductID      ProductName              Category  Price  CustomerRating  \
# 38        209  Travel Backpack           Accessories     30             3.9
# 45        216       Yoga Block        Fitness & Yoga     10             3.8
# 20         21       Headphones           Electronics     35             4.2
# 23         24          Perfume                Beauty     55             4.1
# 47        218     Hiking Boots  Outdoor & Recreation     60             4.4
#
#    PromotionType CustomerAge  ShippingTime  CustomerSatisfaction ShippingDate
# 38      Discount      Senior             4                     3   12/18/2021
# 45           NaN       Young             2                     2   09/01/2021
# 20  Bundle Offer       Adult             3                     4   08/17/2021
# 23           NaN       Adult             3                     4   02/21/2022
# 47           NaN      Senior             4                     4   07/16/2021

# %%
df.head()
# Out:
#    ProductID      ProductName        Category  Price  CustomerRating  \
# 0          1     Smartphone X     Electronics    500             4.2
# 1          2   Fashion Jacket        Clothing     80             4.5
# 2          3  Kitchen Blender  Home & Kitchen    120             3.8
# 3          4    Running Shoes          Sports     60             4.0
# 4          5           LED TV     Electronics    700             4.3
#
#   PromotionType CustomerAge  ShippingTime  CustomerSatisfaction ShippingDate
# 0      Discount       Young             2                     4   02/15/2022
# 1  Bundle Offer       Adult             3                     5   08/20/2021
# 2           NaN      Senior             4                     3   05/10/2022
# 3      Discount       Young             2                     4   11/03/2022
# 4           NaN       Adult             3                     4   06/27/2021

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ProductID             60 non-null     int64
#  1   ProductName           60 non-null     object
#  2   Category              60 non-null     object
#  3   Price                 60 non-null     int64
#  4   CustomerRating        60 non-null     float64
#  5   PromotionType         25 non-null     object
#  6   CustomerAge           60 non-null     object
#  7   ShippingTime          60 non-null     int64
#  8   CustomerSatisfaction  60 non-null     int64
#  9   ShippingDate          60 non-null     object
# dtypes: float64(1), int64(4), object(5)
# memory usage: 4.8+ KB

# %%
df.describe()
# Out:
#         ProductID       Price  CustomerRating  ShippingTime  \
# count   60.000000   60.000000       60.000000     60.000000
# mean   115.500000   69.383333        4.106667      2.966667
# std    101.220936  110.925550        0.277926      0.822701
# min      1.000000    8.000000        3.500000      2.000000
# 25%     15.750000   23.750000        3.900000      2.000000
# 50%    115.500000   40.000000        4.100000      3.000000
# 75%    215.250000   70.000000        4.300000      4.000000
# max    230.000000  700.000000        4.600000      4.000000
#
#        CustomerSatisfaction
# count             60.000000
# mean               3.600000
# std                0.994902
# min                2.000000
# 25%                3.000000
# 50%                4.000000
# 75%                4.000000
# max                5.000000

# %%
df.describe().transpose()
# Out:
#                       count        mean         std  min    25%    50%  \
# ProductID              60.0  115.500000  101.220936  1.0  15.75  115.5
# Price                  60.0   69.383333  110.925550  8.0  23.75   40.0
# CustomerRating         60.0    4.106667    0.277926  3.5   3.90    4.1
# ShippingTime           60.0    2.966667    0.822701  2.0   2.00    3.0
# CustomerSatisfaction   60.0    3.600000    0.994902  2.0   3.00    4.0
#
#                          75%    max
# ProductID             215.25  230.0
# Price                  70.00  700.0
# CustomerRating          4.30    4.6
# ShippingTime            4.00    4.0
# CustomerSatisfaction    4.00    5.0

# %%
df.isnull().sum()
# Out:
# ProductID                0
# ProductName              0
# Category                 0
# Price                    0
# CustomerRating           0
# PromotionType           35
# CustomerAge              0
# ShippingTime             0
# CustomerSatisfaction     0
# ShippingDate             0
# dtype: int64

# %%
df.isnull().mean()*100
# Out:
# ProductID                0.000000
# ProductName              0.000000
# Category                 0.000000
# Price                    0.000000
# CustomerRating           0.000000
# PromotionType           58.333333
# CustomerAge              0.000000
# ShippingTime             0.000000
# CustomerSatisfaction     0.000000
# ShippingDate             0.000000
# dtype: float64

# %%
df.drop('PromotionType',axis=1, inplace=True)

# %%
df.isnull().sum()
# Out:
# ProductID               0
# ProductName             0
# Category                0
# Price                   0
# CustomerRating          0
# CustomerAge             0
# ShippingTime            0
# CustomerSatisfaction    0
# ShippingDate            0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['ProductName'].nunique()
# Out:
# 60

# %%
df['ProductName'].unique()
# Out:
# array(['Smartphone X', 'Fashion Jacket', 'Kitchen Blender',
#        'Running Shoes', 'LED TV', 'Makeup Kit', 'Home Decor Items',
#        'Smartwatch', 'Sneakers', 'Instant Pot', 'Laptop Bag', 'Yoga Mat',
#        'Blow Dryer', 'Coffee Maker', 'Wireless Earbuds', 'Running Gear',
#        'Skin Care Set', 'Desk Organizer', 'Tablet', 'Workout Clothes',
#        'Headphones', 'Winter Coat', 'Toaster', 'Perfume', 'Backpack',
#        'Smart Home Device', 'Running Shorts', 'Compact Mirror',
#        'Desk Lamp', 'Gaming Console', 'Wireless Mouse', 'Comforter Set',
#        'Running Watch', 'Back Massager', 'Stylish Sunglasses',
#        'Culinary Knife Set', 'Gaming Keyboard', 'Outdoor Tent',
#        'Travel Backpack', 'Air Fryer', 'Fitness Tracker',
#        'Portable Charger', 'Bike Helmet', 'Spiralizer',
#        'Bluetooth Speaker', 'Yoga Block', 'Tea Set', 'Hiking Boots',
#        'Lunch Box', 'Smart Thermostat', 'Resistance Bands',
# ...

# %%
import seaborn as sns

# %%
plt.figure(figsize=(18,7))
sns.countplot(data=df, x="Category",order=df['Category'].value_counts().index)
plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# <!-- pic plot -->

# %% [markdown]
# #  PIE Plot

# %%
plt.figure(figsize=(10,5))

df['CustomerAge'].value_counts().plot(kind='pie',autopct="%.2f")
plt.show()

# %%
plt.hist(df['CustomerRating'])
plt.show()

# %%
sns.distplot(df['Price'])
plt.show()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_11596\708458291.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Price'])

# %%
sns.distplot(df['ShippingTime'])
plt.show()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_11596\3823191722.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['ShippingTime'])

# %%
sns.boxplot(df['CustomerRating'])
plt.show()

# %%
plt.scatter(df['Price'] , df['ProductID'])

# %%
sns.scatterplot(data=df)
plt.show()

# %%
sns.lineplot(x='Price',y='CustomerRating',data=df)
plt.show()

# %%
df.columns
# Out:
# Index(['ProductID', 'ProductName', 'Category', 'Price', 'CustomerRating',
#        'CustomerAge', 'ShippingTime', 'CustomerSatisfaction', 'ShippingDate'],
#       dtype='object')

# %%
sns.barplot(x='CustomerRating',y='CustomerSatisfaction' ,data=df)
# Out:
# <Axes: xlabel='CustomerRating', ylabel='CustomerSatisfaction'>

# %%
sns.pairplot(df)

# %%
sns.clustermap(pd.crosstab(df['CustomerAge'],df['Category']))

# %%
# sns.heatmap(df.corr(df['CustomerAge'],df['CustomerRating']),annot=True)

# %%
sns.pairplot(df)
